# %%
import numpy as np 
import matplolib.pyplot as plt
# Out:
# The kernel failed to start as the Python Environment 'Hopefield (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
